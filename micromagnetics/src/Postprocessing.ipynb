# %%
import os
os.environ['PATH'] += ":/content/mumax3.10"

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.interpolate import Rbf

# %%
# LABELS
label = "narrowDW"

# %%
# NUMERICAL PARAMETERS
fmax = 0.1e9    # maximum frequency (in Hz) of the sinc pulse
T_tot = 400e-9  # simulation time (longer -> better frequency resolution)
del_t = 250e-12 # the sample time

# %%
def read_mumax3_table(filename):
    """Puts the mumax3 output table in a pandas dataframe"""

    from pandas import read_table
    
    table = read_table(filename)
    table.columns = ' '.join(table.columns).split()[1::2]
    
    return table

# %%
def read_mumax3_ovffiles(outputdir):
    """Load all ovffiles in outputdir into a dictionary of numpy arrays 
    with the ovffilename (without extension) as key"""
    
    from subprocess import run, PIPE, STDOUT
    from glob import glob
    from os import path
    from numpy import load

    # convert all ovf files in the output directory to numpy files
    p = run(["mumax3-convert","-numpy",outputdir+"/*.ovf"], stdout=PIPE, stderr=STDOUT)
    if p.returncode != 0:
        print(p.stdout.decode('UTF-8'))

    # read the numpy files (the converted ovf files)
    fields = {}
    for npyfile in glob(outputdir+"/*.npy"):
        key = path.splitext(path.basename(npyfile))[0]
        fields[key] = load(npyfile)
    
    return fields

# %%
def run_mumax3(script, name, verbose=False):
    """ Executes a mumax3 script and convert ovf files to numpy files
    
    Parameters
    ----------
      script:  string containing the mumax3 input script
      name:    name of the simulation (this will be the name of the script and output dir)
      verbose: print stdout of mumax3 when it is finished
    """
    
    from subprocess import run, PIPE, STDOUT
    from os import path

    scriptfile = name + ".txt" 
    outputdir  = name + ".out"

    # write the input script in scriptfile
    with open(scriptfile, 'w' ) as f:
        f.write(script)
    
    # call mumax3 to execute this script
    p = run(["mumax3","-f",scriptfile], stdout=PIPE, stderr=STDOUT)
    if verbose or p.returncode != 0:
        print(p.stdout.decode('UTF-8'))
        
    if path.exists(outputdir + "/table.txt"):
        table = read_mumax3_table(outputdir + "/table.txt")
    else:
        table = None
        
    fields = read_mumax3_ovffiles(outputdir)
    
    return table, fields

# %%
script=f"""
// Racetrack crystal settings:
length := 200e-9
width := 25e-9
delta := 100e-9
lattice_constant := 200e-9
N_unitcells := 8
Nx := 100
Ny := 256
Nz := 1
Lx := length
Ly := N_unitcells * lattice_constant
dX := length / Nx
dY := Ly / Ny
dZ := 3e-9 / Nz

setGridSize(Nx, Ny, Nz)
setCellSize(dX, dY, dZ)

// Material Constants
Bz := 0.01
Msat = 1273e3
Aex = 10e-12
anisU = vector(0, 0, 1)
Ku1 = 1.5e6
alpha = 0
Xi = 0.2
demagAccuracy = 8
pinning := false

two_racetrack := rect(length, delta+width)
racetrack := rect(length, width)

gap := delta - width

singleR := racetrack.repeat(0, lattice_constant, 0).transl(0, width/2, 0)
twoR := singleR.add(singleR.transl(0, delta, 0))

setgeom(twoR)

// Define regions
defRegion(1, singleR)
defRegion(2, singleR.transl(0, delta, 0))
defRegion(3, racetrack.transl(0, -Ly/2+width/2, 0))
save(regions)

B_ext.setregion(3, vector(0, 0, Bz*sinc(2*pi*{fmax}*(t-{T}/2))))

m.setRegion(1, twoDomain(0, 0, 1, 1, 1, 0, 0, 0, -1))
m.setRegion(2, twoDomain(0, 0, -1, 1, 1, 0, 0, 0, 1))
m.setRegion(3, twoDomain(0, 0, 1, 1, 1, 0, 0, 0, -1))
setPBC(0, 2, 0)
relax()

// Schedule output & save results
autosave(m, {dt})
tableadd(e_total)
tableautosave({dt})

// Run for 1ns with current through the sample
temp.set(1)
j = vector(0, 0, 0)
pol = 1
run({T})
"""

# %%
#table, fields = run_mumax3( script, name="DW_Lattice", verbose=False )

# %%
'''
Extract table and fields, after simulation has run
'''
name = "narrow_DW"

scriptfile = name + ".txt" 
outputdir  = name + ".out"

table = read_mumax3_table(outputdir + "/table.txt") 
fields = read_mumax3_ovffiles(outputdir)

# %%
print(table)

plt.figure()

nanosecond = 1e-9
plt.plot( table["t"]/nanosecond, table["mx"], color='red')
plt.plot( table["t"]/nanosecond, table["my"], color='blue')
plt.plot( table["t"]/nanosecond, table["mz"], color='green')

plt.xlabel("Time (ns)")
plt.ylabel("Magnetization")

plt.show()
# Out:
#                  t            mx        my            mz       E_total
# 0     0.000000e+00  3.076899e-06  0.050317 -3.142790e-09 -1.248281e-16
# 1     2.501622e-10  1.678455e-06  0.050317 -2.153787e-06 -1.248277e-16
# 2     5.000230e-10 -4.015041e-07  0.050317 -2.583103e-06 -1.248272e-16
# 3     7.500450e-10 -1.694205e-07  0.050317 -2.097542e-06 -1.248267e-16
# 4     1.000150e-09  1.930006e-06  0.050317 -2.793182e-06 -1.248264e-16
# ...            ...           ...       ...           ...           ...
# 1595  3.987501e-07 -6.958925e-03  0.041836  6.652111e-03 -1.247727e-16
# 1596  3.990000e-07  1.617558e-03  0.041093  8.595291e-03 -1.247726e-16
# 1597  3.992500e-07  6.042284e-03  0.041940  9.835290e-04 -1.247725e-16
# 1598  3.995001e-07  2.795710e-03  0.042634 -6.384372e-03 -1.247726e-16
# 1599  3.997500e-07 -3.604140e-03  0.041390 -6.135834e-03 -1.247726e-16
#
# [1600 rows x 5 columns]

# %%
'''
Return the value of DW position in a cell.
(By finding a point where mz == 0)
'''
def bisect(f, x_lo, x_hi, n):
    # midpoint
    x_o = (x_lo + x_hi) / 2.0
    # base case, run enough to converge.
    if n == 0:
        return x_o
    # base case, at x_o is 0
    if f(x_o) == 0:
        return x_o
    
    # ascending (-1 --> 1)
    if f(x_lo) < f(x_hi):
        if f(x_o) > 0:
            x_o = bisect(f, x_lo, x_o, n-1)
        else:
            x_o = bisect(f, x_o, x_hi, n-1)
    # descending (1 --> -1)
    else:
        if f(x_o) < 0:
            x_o = bisect(f, x_lo, x_o, n-1)
        else:
            x_o = bisect(f, x_o, x_hi, n-1)
    return x_o

# %%
def findDW(m):
    # *Global* values/ variables
    x_total = m.shape[3]
    y_total = m.shape[2]
    x_mid = int(m.shape[3]/2)

    DW_array = []
    DW_pos = []

    nDW = 0.0
    flag = False

    for iy in range(y_total):
        mx = m[0,0,iy,x_mid]
        my = m[1,0,iy,x_mid]
        mz = m[2,0,iy,x_mid]
        empty = (mx==0) and (my==0) and (mz==0)

        if empty:
            # Just got off the racetrack.
            if flag == True:
                DW_array.append(sum(DW_pos) / nDW)
                DW_pos = []
                nDW = 0
                flag = False
        else:
            # Just entered the racetrack.
            if flag == False:
                flag = True
            f = Rbf(np.arange(x_total), m[2,0,iy,:]) 
            DW_pos.append(bisect(f, 0, x_total, 15))
            nDW += 1
    
    return DW_array

# %%
def findDW_A(m):
    # *Global* values/ variables
    x_total = m.shape[3]
    y_total = m.shape[2]
    x_mid = int(m.shape[3]/2)

    DW_array = []
    DW_pos = []

    nDW = 0.0
    flag = False
    count = -1

    for iy in range(y_total):
        mx = m[0,0,iy,x_mid]
        my = m[1,0,iy,x_mid]
        mz = m[2,0,iy,x_mid]
        empty = (mx==0) and (my==0) and (mz==0)

        if empty:
            # Just got off the racetrack.
            if flag == True:
                if count%2 == 0:
                    DW_array.append(sum(DW_pos) / nDW)
                DW_pos = []
                nDW = 0
                flag = False
        else:
            # Just entered the racetrack.
            if flag == False:
                flag = True
                count += 1
            f = Rbf(np.arange(x_total), m[2,0,iy,:]) 
            DW_pos.append(bisect(f, 0, x_total, 15))
            nDW += 1
    
    return DW_array

# %%
def findDW_B(m):
    # *Global* values/ variables
    x_total = m.shape[3]
    y_total = m.shape[2]
    x_mid = int(m.shape[3]/2)

    DW_array = []
    DW_pos = []

    nDW = 0.0
    flag = False
    count = -1

    for iy in range(y_total):
        mx = m[0,0,iy,x_mid]
        my = m[1,0,iy,x_mid]
        mz = m[2,0,iy,x_mid]
        empty = (mx==0) and (my==0) and (mz==0)

        if empty:
            # Just got off the racetrack.
            if flag == True:
                if count%2 != 0:
                    DW_array.append(sum(DW_pos) / nDW)
                DW_pos = []
                nDW = 0
                flag = False
        else:
            # Just entered the racetrack.
            if flag == False:
                flag = True
                count += 1
            f = Rbf(np.arange(x_total), m[2,0,iy,:]) 
            DW_pos.append(bisect(f, 0, x_total, 15))
            nDW += 1
    
    return DW_array

# %%
pos = []
posA = []
posB = []

for key in sorted(fields.keys())[1175:]:
    if (key != "regions000000") and (key != "regions000001"):
        pos.append(findDW(fields[key]))
        posA.append(findDW_A(fields[key]))
        print("Processing: " + str(key))
        posB.append(findDW_B(fields[key]))
# Out:
# Processing: m000000
# Processing: m000001
# Processing: m000002
# Processing: m000003
# Processing: m000004
# Processing: m000005
# Processing: m000006
# Processing: m000007
# Processing: m000008
# Processing: m000009
# Processing: m000010
# Processing: m000011
# Processing: m000012
# Processing: m000013
# Processing: m000014
# Processing: m000015
# Processing: m000016
# Processing: m000017
# Processing: m000018
# Processing: m000019
# Processing: m000020
# Processing: m000021
# Processing: m000022
# Processing: m000023
# Processing: m000024
# Processing: m000025
# Processing: m000026
# Processing: m000027
# Processing: m000028
# Processing: m000029
# Processing: m000030
# Processing: m000031
# Processing: m000032
# Processing: m000033
# Processing: m000034
# Processing: m000035
# Processing: m000036
# Processing: m000037
# Processing: m000038
# Processing: m000039
# Processing: m000040
# Processing: m000041
# Processing: m000042
# Processing: m000043
# Processing: m000044
# Processing: m000045
# Processing: m000046
# Processing: m000047
# Processing: m000048
# Processing: m000049
# Processing: m000050
# Processing: m000051
# Processing: m000052
# Processing: m000053
# Processing: m000054
# Processing: m000055
# Processing: m000056
# Processing: m000057
# Processing: m000058
# Processing: m000059
# Processing: m000060
# Processing: m000061
# Processing: m000062
# Processing: m000063
# Processing: m000064
# Processing: m000065
# Processing: m000066
# Processing: m000067
# Processing: m000068
# Processing: m000069
# Processing: m000070
# Processing: m000071
# Processing: m000072
# Processing: m000073
# Processing: m000074
# Processing: m000075
# Processing: m000076
# Processing: m000077
# Processing: m000078
# Processing: m000079
# Processing: m000080
# Processing: m000081
# Processing: m000082
# Processing: m000083
# Processing: m000084
# Processing: m000085
# Processing: m000086
# Processing: m000087
# Processing: m000088
# Processing: m000089
# Processing: m000090
# Processing: m000091
# Processing: m000092
# Processing: m000093
# Processing: m000094
# Processing: m000095
# Processing: m000096
# Processing: m000097
# Processing: m000098
# Processing: m000099
# Processing: m000100
# Processing: m000101
# Processing: m000102
# Processing: m000103
# Processing: m000104
# Processing: m000105
# Processing: m000106
# Processing: m000107
# Processing: m000108
# Processing: m000109
# Processing: m000110
# Processing: m000111
# Processing: m000112
# Processing: m000113
# Processing: m000114
# Processing: m000115
# Processing: m000116
# Processing: m000117
# Processing: m000118
# Processing: m000119
# Processing: m000120
# Processing: m000121
# Processing: m000122
# Processing: m000123
# Processing: m000124
# Processing: m000125
# Processing: m000126
# Processing: m000127
# Processing: m000128
# Processing: m000129
# Processing: m000130
# Processing: m000131
# Processing: m000132
# Processing: m000133
# Processing: m000134
# Processing: m000135
# Processing: m000136
# Processing: m000137
# Processing: m000138
# Processing: m000139
# Processing: m000140
# Processing: m000141
# Processing: m000142
# Processing: m000143
# Processing: m000144
# Processing: m000145
# Processing: m000146
# Processing: m000147
# Processing: m000148
# Processing: m000149
# Processing: m000150
# Processing: m000151
# Processing: m000152
# Processing: m000153
# Processing: m000154
# Processing: m000155
# Processing: m000156
# Processing: m000157
# Processing: m000158
# Processing: m000159
# Processing: m000160
# Processing: m000161
# Processing: m000162
# Processing: m000163
# Processing: m000164
# Processing: m000165
# Processing: m000166
# Processing: m000167
# Processing: m000168
# Processing: m000169
# Processing: m000170
# Processing: m000171
# Processing: m000172
# Processing: m000173
# Processing: m000174
# Processing: m000175
# Processing: m000176
# Processing: m000177
# Processing: m000178
# Processing: m000179
# Processing: m000180
# Processing: m000181
# Processing: m000182
# Processing: m000183
# Processing: m000184
# Processing: m000185
# Processing: m000186
# Processing: m000187
# Processing: m000188
# Processing: m000189
# Processing: m000190
# Processing: m000191
# Processing: m000192
# Processing: m000193
# Processing: m000194
# Processing: m000195
# Processing: m000196
# Processing: m000197
# Processing: m000198
# Processing: m000199
# Processing: m000200
# Processing: m000201
# Processing: m000202
# Processing: m000203
# Processing: m000204
# Processing: m000205
# Processing: m000206
# Processing: m000207
# Processing: m000208
# Processing: m000209
# Processing: m000210
# Processing: m000211
# Processing: m000212
# Processing: m000213
# Processing: m000214
# Processing: m000215
# Processing: m000216
# Processing: m000217
# Processing: m000218
# Processing: m000219
# Processing: m000220
# Processing: m000221
# Processing: m000222
# Processing: m000223
# Processing: m000224
# Processing: m000225
# Processing: m000226
# Processing: m000227
# Processing: m000228
# Processing: m000229
# Processing: m000230
# Processing: m000231
# Processing: m000232
# Processing: m000233
# Processing: m000234
# Processing: m000235
# Processing: m000236
# Processing: m000237
# Processing: m000238
# Processing: m000239
# Processing: m000240
# Processing: m000241
# Processing: m000242
# Processing: m000243
# Processing: m000244
# Processing: m000245
# Processing: m000246
# Processing: m000247
# Processing: m000248
# Processing: m000249
# Processing: m000250
# Processing: m000251
# Processing: m000252
# Processing: m000253
# Processing: m000254
# Processing: m000255
# Processing: m000256
# Processing: m000257
# Processing: m000258
# Processing: m000259
# Processing: m000260
# Processing: m000261
# Processing: m000262
# Processing: m000263
# Processing: m000264
# Processing: m000265
# Processing: m000266
# Processing: m000267
# Processing: m000268
# Processing: m000269
# Processing: m000270
# Processing: m000271
# Processing: m000272
# Processing: m000273
# Processing: m000274
# Processing: m000275
# Processing: m000276
# Processing: m000277
# Processing: m000278
# Processing: m000279
# Processing: m000280
# Processing: m000281
# Processing: m000282
# Processing: m000283
# Processing: m000284
# Processing: m000285
# Processing: m000286
# Processing: m000287
# Processing: m000288
# Processing: m000289
# Processing: m000290
# Processing: m000291
# Processing: m000292
# Processing: m000293
# Processing: m000294
# Processing: m000295
# Processing: m000296
# Processing: m000297
# Processing: m000298
# Processing: m000299
# Processing: m000300
# Processing: m000301
# Processing: m000302
# Processing: m000303
# Processing: m000304
# Processing: m000305
# Processing: m000306
# Processing: m000307
# Processing: m000308
# Processing: m000309
# Processing: m000310
# Processing: m000311
# Processing: m000312
# Processing: m000313
# Processing: m000314
# Processing: m000315
# Processing: m000316
# Processing: m000317
# Processing: m000318
# Processing: m000319
# Processing: m000320
# Processing: m000321
# Processing: m000322
# Processing: m000323
# Processing: m000324
# Processing: m000325
# Processing: m000326
# Processing: m000327
# Processing: m000328
# Processing: m000329
# Processing: m000330
# Processing: m000331
# Processing: m000332
# Processing: m000333
# Processing: m000334
# Processing: m000335
# Processing: m000336
# Processing: m000337
# Processing: m000338
# Processing: m000339
# Processing: m000340
# Processing: m000341
# Processing: m000342
# Processing: m000343
# Processing: m000344
# Processing: m000345
# Processing: m000346
# Processing: m000347
# Processing: m000348
# Processing: m000349
# Processing: m000350
# Processing: m000351
# Processing: m000352
# Processing: m000353
# Processing: m000354
# Processing: m000355
# Processing: m000356
# Processing: m000357
# Processing: m000358
# Processing: m000359
# Processing: m000360
# Processing: m000361
# Processing: m000362
# Processing: m000363
# Processing: m000364
# Processing: m000365
# Processing: m000366
# Processing: m000367
# Processing: m000368
# Processing: m000369
# Processing: m000370
# Processing: m000371
# Processing: m000372
# Processing: m000373
# Processing: m000374
# Processing: m000375
# Processing: m000376
# Processing: m000377
# Processing: m000378
# Processing: m000379
# Processing: m000380
# Processing: m000381
# Processing: m000382
# Processing: m000383
# Processing: m000384
# Processing: m000385
# Processing: m000386
# Processing: m000387
# Processing: m000388
# Processing: m000389
# Processing: m000390
# Processing: m000391
# Processing: m000392
# Processing: m000393
# Processing: m000394
# Processing: m000395
# Processing: m000396
# Processing: m000397
# Processing: m000398
# Processing: m000399
# Processing: m000400
# Processing: m000401
# Processing: m000402
# Processing: m000403
# Processing: m000404
# Processing: m000405
# Processing: m000406
# Processing: m000407
# Processing: m000408
# Processing: m000409
# Processing: m000410
# Processing: m000411
# Processing: m000412
# Processing: m000413
# Processing: m000414
# Processing: m000415
# Processing: m000416
# Processing: m000417
# Processing: m000418
# Processing: m000419
# Processing: m000420
# Processing: m000421
# Processing: m000422
# Processing: m000423
# Processing: m000424
# Processing: m000425
# Processing: m000426
# Processing: m000427
# Processing: m000428
# Processing: m000429
# Processing: m000430
# Processing: m000431
# Processing: m000432
# Processing: m000433
# Processing: m000434
# Processing: m000435
# Processing: m000436
# Processing: m000437
# Processing: m000438
# Processing: m000439
# Processing: m000440
# Processing: m000441
# Processing: m000442
# Processing: m000443
# Processing: m000444
# Processing: m000445
# Processing: m000446
# Processing: m000447
# Processing: m000448
# Processing: m000449
# Processing: m000450
# Processing: m000451
# Processing: m000452
# Processing: m000453
# Processing: m000454
# Processing: m000455
# Processing: m000456
# Processing: m000457
# Processing: m000458
# Processing: m000459
# Processing: m000460
# Processing: m000461
# Processing: m000462
# Processing: m000463
# Processing: m000464
# Processing: m000465
# Processing: m000466
# Processing: m000467
# Processing: m000468
# Processing: m000469
# Processing: m000470
# Processing: m000471
# Processing: m000472
# Processing: m000473
# Processing: m000474
# Processing: m000475
# Processing: m000476
# Processing: m000477
# Processing: m000478
# Processing: m000479
# Processing: m000480
# Processing: m000481
# Processing: m000482
# Processing: m000483
# Processing: m000484
# Processing: m000485
# Processing: m000486
# Processing: m000487
# Processing: m000488
# Processing: m000489
# Processing: m000490
# Processing: m000491
# Processing: m000492
# Processing: m000493
# Processing: m000494
# Processing: m000495
# Processing: m000496
# Processing: m000497
# Processing: m000498
# Processing: m000499
# Processing: m000500
# Processing: m000501
# Processing: m000502
# Processing: m000503
# Processing: m000504
# Processing: m000505
# Processing: m000506
# Processing: m000507
# Processing: m000508
# Processing: m000509
# Processing: m000510
# Processing: m000511
# Processing: m000512
# Processing: m000513
# Processing: m000514
# Processing: m000515
# Processing: m000516
# Processing: m000517
# Processing: m000518
# Processing: m000519
# Processing: m000520
# Processing: m000521
# Processing: m000522
# Processing: m000523
# Processing: m000524
# Processing: m000525
# Processing: m000526
# Processing: m000527
# Processing: m000528
# Processing: m000529
# Processing: m000530
# Processing: m000531
# Processing: m000532
# Processing: m000533
# Processing: m000534
# Processing: m000535
# Processing: m000536
# Processing: m000537
# Processing: m000538
# Processing: m000539
# Processing: m000540
# Processing: m000541
# Processing: m000542
# Processing: m000543
# Processing: m000544
# Processing: m000545
# Processing: m000546
# Processing: m000547
# Processing: m000548
# Processing: m000549
# Processing: m000550
# Processing: m000551
# Processing: m000552
# Processing: m000553
# Processing: m000554
# Processing: m000555
# Processing: m000556
# Processing: m000557
# Processing: m000558
# Processing: m000559
# Processing: m000560
# Processing: m000561
# Processing: m000562
# Processing: m000563
# Processing: m000564
# Processing: m000565
# Processing: m000566
# Processing: m000567
# Processing: m000568
# Processing: m000569
# Processing: m000570
# Processing: m000571
# Processing: m000572
# Processing: m000573
# Processing: m000574
# Processing: m000575
# Processing: m000576
# Processing: m000577
# Processing: m000578
# Processing: m000579
# Processing: m000580
# Processing: m000581
# Processing: m000582
# Processing: m000583
# Processing: m000584
# Processing: m000585
# Processing: m000586
# Processing: m000587
# Processing: m000588
# Processing: m000589
# Processing: m000590
# Processing: m000591
# Processing: m000592
# Processing: m000593
# Processing: m000594
# Processing: m000595
# Processing: m000596
# Processing: m000597
# Processing: m000598
# Processing: m000599
# Processing: m000600
# Processing: m000601
# Processing: m000602
# Processing: m000603
# Processing: m000604
# Processing: m000605
# Processing: m000606
# Processing: m000607
# Processing: m000608
# Processing: m000609
# Processing: m000610
# Processing: m000611
# Processing: m000612
# Processing: m000613
# Processing: m000614
# Processing: m000615
# Processing: m000616
# Processing: m000617
# Processing: m000618
# Processing: m000619
# Processing: m000620
# Processing: m000621
# Processing: m000622
# Processing: m000623
# Processing: m000624
# Processing: m000625
# Processing: m000626
# Processing: m000627
# Processing: m000628
# Processing: m000629
# Processing: m000630
# Processing: m000631
# Processing: m000632
# Processing: m000633
# Processing: m000634
# Processing: m000635
# Processing: m000636
# Processing: m000637
# Processing: m000638
# Processing: m000639
# Processing: m000640
# Processing: m000641
# Processing: m000642
# Processing: m000643
# Processing: m000644
# Processing: m000645
# Processing: m000646
# Processing: m000647
# Processing: m000648
# Processing: m000649
# Processing: m000650
# Processing: m000651
# Processing: m000652
# Processing: m000653
# Processing: m000654
# Processing: m000655
# Processing: m000656
# Processing: m000657
# Processing: m000658
# Processing: m000659
# Processing: m000660
# Processing: m000661
# Processing: m000662
# Processing: m000663
# Processing: m000664
# Processing: m000665
# Processing: m000666
# Processing: m000667
# Processing: m000668
# Processing: m000669
# Processing: m000670
# Processing: m000671
# Processing: m000672
# Processing: m000673
# Processing: m000674
# Processing: m000675
# Processing: m000676
# Processing: m000677
# Processing: m000678
# Processing: m000679
# Processing: m000680
# Processing: m000681
# Processing: m000682
# Processing: m000683
# Processing: m000684
# Processing: m000685
# Processing: m000686
# Processing: m000687
# Processing: m000688
# Processing: m000689
# Processing: m000690
# Processing: m000691
# Processing: m000692
# Processing: m000693
# Processing: m000694
# Processing: m000695
# Processing: m000696
# Processing: m000697
# Processing: m000698
# Processing: m000699
# Processing: m000700
# Processing: m000701
# Processing: m000702
# Processing: m000703
# Processing: m000704
# Processing: m000705
# Processing: m000706
# Processing: m000707
# Processing: m000708
# Processing: m000709
# Processing: m000710
# Processing: m000711
# Processing: m000712
# Processing: m000713
# Processing: m000714
# Processing: m000715
# Processing: m000716
# Processing: m000717
# Processing: m000718
# Processing: m000719
# Processing: m000720
# Processing: m000721
# Processing: m000722
# Processing: m000723
# Processing: m000724
# Processing: m000725
# Processing: m000726
# Processing: m000727
# Processing: m000728
# Processing: m000729
# Processing: m000730
# Processing: m000731
# Processing: m000732
# Processing: m000733
# Processing: m000734
# Processing: m000735
# Processing: m000736
# Processing: m000737
# Processing: m000738
# Processing: m000739
# Processing: m000740
# Processing: m000741
# Processing: m000742
# Processing: m000743
# Processing: m000744
# Processing: m000745
# Processing: m000746
# Processing: m000747
# Processing: m000748
# Processing: m000749
# Processing: m000750
# Processing: m000751
# Processing: m000752
# Processing: m000753
# Processing: m000754
# Processing: m000755
# Processing: m000756
# Processing: m000757
# Processing: m000758
# Processing: m000759
# Processing: m000760
# Processing: m000761
# Processing: m000762
# Processing: m000763
# Processing: m000764
# Processing: m000765
# Processing: m000766
# Processing: m000767
# Processing: m000768
# Processing: m000769
# Processing: m000770
# Processing: m000771
# Processing: m000772
# Processing: m000773
# Processing: m000774
# Processing: m000775
# Processing: m000776
# Processing: m000777
# Processing: m000778
# Processing: m000779
# Processing: m000780
# Processing: m000781
# Processing: m000782
# Processing: m000783
# Processing: m000784
# Processing: m000785
# Processing: m000786
# Processing: m000787
# Processing: m000788
# Processing: m000789
# Processing: m000790
# Processing: m000791
# Processing: m000792
# Processing: m000793
# Processing: m000794
# Processing: m000795
# Processing: m000796
# Processing: m000797
# Processing: m000798
# Processing: m000799
# Processing: m000800
# Processing: m000801
# Processing: m000802
# Processing: m000803
# Processing: m000804
# Processing: m000805
# Processing: m000806
# Processing: m000807
# Processing: m000808
# Processing: m000809
# Processing: m000810
# Processing: m000811
# Processing: m000812
# Processing: m000813
# Processing: m000814
# Processing: m000815
# Processing: m000816
# Processing: m000817
# Processing: m000818
# Processing: m000819
# Processing: m000820
# Processing: m000821
# Processing: m000822
# Processing: m000823
# Processing: m000824
# Processing: m000825
# Processing: m000826
# Processing: m000827
# Processing: m000828
# Processing: m000829
# Processing: m000830
# Processing: m000831
# Processing: m000832
# Processing: m000833
# Processing: m000834
# Processing: m000835
# Processing: m000836
# Processing: m000837
# Processing: m000838
# Processing: m000839
# Processing: m000840
# Processing: m000841
# Processing: m000842
# Processing: m000843
# Processing: m000844
# Processing: m000845
# Processing: m000846
# Processing: m000847
# Processing: m000848
# Processing: m000849
# Processing: m000850
# Processing: m000851
# Processing: m000852
# Processing: m000853
# Processing: m000854
# Processing: m000855
# Processing: m000856
# Processing: m000857
# Processing: m000858
# Processing: m000859
# Processing: m000860
# Processing: m000861
# Processing: m000862
# Processing: m000863
# Processing: m000864
# Processing: m000865
# Processing: m000866
# Processing: m000867
# Processing: m000868
# Processing: m000869
# Processing: m000870
# Processing: m000871
# Processing: m000872
# Processing: m000873
# Processing: m000874
# Processing: m000875
# Processing: m000876
# Processing: m000877
# Processing: m000878
# Processing: m000879
# Processing: m000880
# Processing: m000881
# Processing: m000882
# Processing: m000883
# Processing: m000884
# Processing: m000885
# Processing: m000886
# Processing: m000887
# Processing: m000888
# Processing: m000889
# Processing: m000890
# Processing: m000891
# Processing: m000892
# Processing: m000893
# Processing: m000894
# Processing: m000895
# Processing: m000896
# Processing: m000897
# Processing: m000898
# Processing: m000899
# Processing: m000900
# Processing: m000901
# Processing: m000902
# Processing: m000903
# Processing: m000904
# Processing: m000905
# Processing: m000906
# Processing: m000907
# Processing: m000908
# Processing: m000909
# Processing: m000910
# Processing: m000911
# Processing: m000912
# Processing: m000913
# Processing: m000914
# Processing: m000915
# Processing: m000916
# Processing: m000917
# Processing: m000918
# Processing: m000919
# Processing: m000920
# Processing: m000921
# Processing: m000922
# Processing: m000923
# Processing: m000924
# Processing: m000925
# Processing: m000926
# Processing: m000927
# Processing: m000928
# Processing: m000929
# Processing: m000930
# Processing: m000931
# Processing: m000932
# Processing: m000933
# Processing: m000934
# Processing: m000935
# Processing: m000936
# Processing: m000937
# Processing: m000938
# Processing: m000939
# Processing: m000940
# Processing: m000941
# Processing: m000942
# Processing: m000943
# Processing: m000944
# Processing: m000945
# Processing: m000946
# Processing: m000947
# Processing: m000948
# Processing: m000949
# Processing: m000950
# Processing: m000951
# Processing: m000952
# Processing: m000953
# Processing: m000954
# Processing: m000955
# Processing: m000956
# Processing: m000957
# Processing: m000958
# Processing: m000959
# Processing: m000960
# Processing: m000961
# Processing: m000962
# Processing: m000963
# Processing: m000964
# Processing: m000965
# Processing: m000966
# Processing: m000967
# Processing: m000968
# Processing: m000969
# Processing: m000970
# Processing: m000971
# Processing: m000972
# Processing: m000973
# Processing: m000974
# Processing: m000975
# Processing: m000976
# Processing: m000977
# Processing: m000978
# Processing: m000979
# Processing: m000980
# Processing: m000981
# Processing: m000982
# Processing: m000983
# Processing: m000984
# Processing: m000985
# Processing: m000986
# Processing: m000987
# Processing: m000988
# Processing: m000989
# Processing: m000990
# Processing: m000991
# Processing: m000992
# Processing: m000993
# Processing: m000994
# Processing: m000995
# Processing: m000996
# Processing: m000997
# Processing: m000998
# Processing: m000999
# Processing: m001000
# Processing: m001001
# Processing: m001002
# Processing: m001003
# Processing: m001004
# Processing: m001005
# Processing: m001006
# Processing: m001007
# Processing: m001008
# Processing: m001009
# Processing: m001010
# Processing: m001011
# Processing: m001012
# Processing: m001013
# Processing: m001014
# Processing: m001015
# Processing: m001016
# Processing: m001017
# Processing: m001018
# Processing: m001019
# Processing: m001020
# Processing: m001021
# Processing: m001022
# Processing: m001023
# Processing: m001024
# Processing: m001025
# Processing: m001026
# Processing: m001027
# Processing: m001028
# Processing: m001029
# Processing: m001030
# Processing: m001031
# Processing: m001032
# Processing: m001033
# Processing: m001034
# Processing: m001035
# Processing: m001036
# Processing: m001037
# Processing: m001038
# Processing: m001039
# Processing: m001040
# Processing: m001041
# Processing: m001042
# Processing: m001043
# Processing: m001044
# Processing: m001045
# Processing: m001046
# Processing: m001047
# Processing: m001048
# Processing: m001049
# Processing: m001050
# Processing: m001051
# Processing: m001052
# Processing: m001053
# Processing: m001054
# Processing: m001055
# Processing: m001056
# Processing: m001057
# Processing: m001058
# Processing: m001059
# Processing: m001060
# Processing: m001061
# Processing: m001062
# Processing: m001063
# Processing: m001064
# Processing: m001065
# Processing: m001066
# Processing: m001067
# Processing: m001068
# Processing: m001069
# Processing: m001070
# Processing: m001071
# Processing: m001072
# Processing: m001073
# Processing: m001074
# Processing: m001075
# Processing: m001076
# Processing: m001077
# Processing: m001078
# Processing: m001079
# Processing: m001080
# Processing: m001081
# Processing: m001082
# Processing: m001083
# Processing: m001084
# Processing: m001085
# Processing: m001086
# Processing: m001087
# Processing: m001088
# Processing: m001089
# Processing: m001090
# Processing: m001091
# Processing: m001092
# Processing: m001093
# Processing: m001094
# Processing: m001095
# Processing: m001096
# Processing: m001097
# Processing: m001098
# Processing: m001099
# Processing: m001100
# Processing: m001101
# Processing: m001102
# Processing: m001103
# Processing: m001104
# Processing: m001105
# Processing: m001106
# Processing: m001107
# Processing: m001108
# Processing: m001109
# Processing: m001110
# Processing: m001111
# Processing: m001112
# Processing: m001113
# Processing: m001114
# Processing: m001115
# Processing: m001116
# Processing: m001117
# Processing: m001118
# Processing: m001119
# Processing: m001120
# Processing: m001121
# Processing: m001122
# Processing: m001123
# Processing: m001124
# Processing: m001125
# Processing: m001126
# Processing: m001127
# Processing: m001128
# Processing: m001129
# Processing: m001130
# Processing: m001131
# Processing: m001132
# Processing: m001133
# Processing: m001134
# Processing: m001135
# Processing: m001136
# Processing: m001137
# Processing: m001138
# Processing: m001139
# Processing: m001140
# Processing: m001141
# Processing: m001142
# Processing: m001143
# Processing: m001144
# Processing: m001145
# Processing: m001146
# Processing: m001147
# Processing: m001148
# Processing: m001149
# Processing: m001150
# Processing: m001151
# Processing: m001152
# Processing: m001153
# Processing: m001154
# Processing: m001155
# Processing: m001156
# Processing: m001157
# Processing: m001158
# Processing: m001159
# Processing: m001160
# Processing: m001161
# Processing: m001162
# Processing: m001163
# Processing: m001164
# Processing: m001165
# Processing: m001166
# Processing: m001167
# Processing: m001168
# Processing: m001169
# Processing: m001170
# Processing: m001171
# Processing: m001172
# Processing: m001173
# Processing: m001174
# Processing: m001175
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 7
#       5 for key in sorted(fields.keys()):
#       6     if key != "regions000000":
# ----> 7         pos.append(findDW(fields[key]))
#       8         posA.append(findDW_A(fields[key]))
#       9         print("Processing: " + str(key))
#
# Cell In[12], line 15, in findDW(m)
#      13 for iy in range(y_total):
#      14     mx = m[0,0,iy,x_mid]
# ---> 15     my = m[1,0,iy,x_mid]
#      16     mz = m[2,0,iy,x_mid]
#      17     empty = (mx==0) and (my==0) and (mz==0)
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
for key in sorted(fields.keys())[1176:]:
    if (key != "regions000000") and (key != "regions000001"):
        pos.append(findDW(fields[key]))
        posA.append(findDW_A(fields[key]))
        print("Processing: " + str(key))
        posB.append(findDW_B(fields[key]))
# Out:
# Processing: m001176
# Processing: m001177
# Processing: m001178
# Processing: m001179
# Processing: m001180
# Processing: m001181
# Processing: m001182
# Processing: m001183
# Processing: m001184
# Processing: m001185
# Processing: m001186

# %%
"""
Saving copy
"""
f = open('data/pos.txt',mode='w')
f.write(str(pos))

f = open('data/posA.txt',mode='w')
f.write(str(posA))

f = open('data/posB.txt',mode='w')
f.write(str(posB))
# Out:
# 180093

# %%
'''
Pos data extraction
'''
from ast import literal_eval
# 1. IMPORT .TXT AS STRING
posStr = open("/home/jiwoop/rnf/pastSim/dwlattice/micromagnetics/data/pos.txt", "r").read()
posEvenStr = open("/home/jiwoop/rnf/pastSim/dwlattice/micromagnetics/data/posA.txt", 'r').read()
posOddStr = open("/home/jiwoop/rnf/pastSim/dwlattice/micromagnetics/data/posB.txt", "r").read()

# 2. CONVERT .TXT TO LIST
posList = literal_eval(posStr)
posEList = literal_eval(posEvenStr)
posOList = literal_eval(posOddStr)

# 3. CONVERT LIST TO NP ARRAY
pos = np.array(posList)
posE = np.array(posEList)
posO = np.array(posOList)

# %%
from matplotlib.colors import LogNorm

# %%
pos_fft = np.fft.fft2(pos)
pos_fft = np.fft.fftshift(pos_fft)
pos_fft = np.fft.fftshift(pos_fft, axes=(1,))

# Magnitude of complex number array
A = np.abs(pos_fft)**2

plt.figure(figsize=(10,6))

# Show the intensity plot of the 2D FFT
plt.imshow(A, aspect='auto', origin='lower', cmap="inferno", norm=LogNorm())

# plt.xlim([-2e8,2e8])
# plt.ylim([0,fmax])
plt.ylabel("$f$ (Hz)")
plt.xlabel("$k$ (1/m)")

plt.savefig("/home/jiwoop/rnf/dwlattice/micromagnetics/plots" + label + "_spectrogram.png")
plt.show()

# %%
A.shape
# Out:
# (1601, 8)

# %%
import math

# Apply the two dimensional FFT
posE_fft = np.fft.fft2(posE)
posO_fft = np.fft.fft2(posO)
posE_fft = np.fft.fftshift(posE_fft)
posO_fft = np.fft.fftshift(posO_fft)

# Magnitude of complex number array
A = np.add(np.abs(posE_fft)**2, np.abs(posO_fft)**2)

# Plotting params
sizeX = A.shape[1]
sizeY = A.shape[0]
cutoff = 8.5/12

xVals = np.arange(-int(sizeX/2), int(sizeX/2)+1)

x = ['']*(sizeX+1)
x[0] = "-π/a"
x[8] = "π/a"

# Get rid of negative freq
A = A[int(sizeY/2):int(sizeY * cutoff), :]

# Convert to angular freq.
𝜔 =  fmax * 2 * math.pi * 1e-9

# Show the intensity plot of the 2D FFT
plt.figure(figsize=(10,6))
fig, ax = plt.subplots(1, 1)
ax.imshow(A, aspect='auto', origin='lower', cmap="inferno", norm=LogNorm(), extent=[-int(sizeX/2), int(sizeX/2), 0, 𝜔 * cutoff])

plt.ylabel("$𝜔$ (rad/ns)")
plt.xlabel("$k$")
ax.set(xticks=xVals, xticklabels=x)

plt.savefig("/home/jiwoop/rnf/dwlattice/micromagnetics/plots" + label + "_bandStruct.png")
plt.show()

# %%
xVals
# Out:
# array([-4, -3, -2, -1,  0,  1,  2,  3,  4])

# %%
# Plot positions along racetracks
by_track = np.transpose(pos)

# %%
n_racetrack = range(by_track.shape[0])
t = range(by_track.shape[1])

plt.figure(figsize=(10, 6), dpi=300)

for nth in n_racetrack:
    plt.plot(t, by_track[nth], label=str(nth+1)+'th')

plt.legend(loc="upper left", fontsize='5')

# %%
from importlib import reload
plt = reload(plt)

n_racetrack = range(by_track.shape[0])

plt.figure(figsize=(10, 6), dpi=300)

# s, m version
# T_vals = np.linspace(0, T, int(T/dt)+1)[:by_track.shape[1]]
# resize_track = by_track * 0.25e-9

# ns, nm version
T_vals = np.linspace(0, T, int(T/dt)+2)[:by_track.shape[1]] * 1e9
resize_track = by_track * 0.25

for nth in n_racetrack:
    plt.plot(T_vals, resize_track[nth], label=str(nth+1)+'th')

plt.legend(loc="upper left", fontsize='5')

# ns, nm version
plt.xlabel("Time (ns)")
plt.ylabel("DW Position (nm)")
plt.savefig("/home/jiwoop/rnf/pastSim/dwlattice/micromagnetics/plots/" + label + "_thin_pos_v_t.png")

# %%
plt.figure(figsize=(5, 3), dpi=300)

for nth in n_racetrack:
    plt.plot(T_vals, resize_track[nth], label=str(nth+1)+'th')

plt.legend(loc="upper left", fontsize='5')

# ns, nm version
plt.xlabel("Time (ns)")
plt.ylabel("DW Position (nm)")
plt.savefig("/home/jiwoop/rnf/pastSim/dwlattice/micromagnetics/plots/" + label + "_THICK_pos_v_t.png")
